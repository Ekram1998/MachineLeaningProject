# %% [markdown]
# **Description :**
# - The object of this diabets dataset is to predict whether patient has diabetes or not.The datasets consists of several medical predictor(Independent)variable and one target variable(outcome).Predictor variable includes pregnancies,Glucose,Blood Pressure, Skin Thickness,Insulin,BMI,DiabetesPedigreeFunction,age,and Outcome.

# %% [markdown]
# **Number of the columns with their meanings :**
#
# 1.   Pregnancies --> Number of items pregnant
# 2.   Glucose --> Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3.   BloodPressure --> Diastolic blood pressure(mm Hg)
# 4.   SkinThickness --> Triceps skin fold thickness (mm)
# 5.   Insulin --> 2-Hours serum insulin (mu U/ml)
# 6.   BMI --> Body mass index (weight in kg/(height in m)^2)
# 7.   DiabetesPedigreeFunction --> Diabetes pedigree function
# 8.   Age --> Age(years)
# 9.   Outcome --> Class Variable (0 or 1)
#         - 268 of 768 are 1
#         - 500 of 768 are 0

# %% [markdown]
# **Step 1: Import libraries like Numpy, Padas, Matplotlib, Seaborn and Scikit-learn(Sklearn)**

# %%
# Numpy 
import numpy as np

# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt

# Seaborn
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Step 2: Load the Dataset**

# %%
# Load dataseet

df = pd.read_csv('/content/drive/MyDrive/ML_DataFile/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# **Step 3: Exploratory Data Analysis**

# %%
df.head()  #get familier with dataset, display the top 5 data records
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
df.tail() # get familier with dataset, display the last 5 data records
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [5 rows x 9 columns]

# %%
df.sample(5) # get familier with dataset, display randomly 5 data records
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 241            4       91  ...   22        0
# 398            3       82  ...   25        0
# 349            5        0  ...   37        1
# 277            0      104  ...   23        0
# 89             1      107  ...   24        0
#
# [5 rows x 9 columns]

# %%
df.shape # getting to know about rows and columns we're dealing with - 768 rows , 9 columns
# Out:
# (768, 9)

# %%
df.columns # learning about the columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes # knowledge of data type helps for computation
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info() #  Print a concise summary of a DataFrame. 
          #  This method prints information about a DataFrame including the index dtype and columns,
          #  non-null values and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe() #helps us to understand how data has been spread across the table.
# count :- the number of NoN-empty rows in a feature.
# mean :- mean value of that feature.
# std :- Standard Deviation Value of that feature.
# min :- minimum value of that feature.
# max :- maximum value of that feature.
# 25%, 50%, and 75% are the percentile/quartile of each features.
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# **Step 4: Data Cleaning**

# %%
df.shape  # Check the shape before the duplicate values
# Out:
# (768, 9)

# %%
#dropping duplicate values - checking if there are any duplicate rows and dropping if any
df=df.drop_duplicates()

# %%
df.shape  # check the shape after drop the duplicate values
# Out:
# (768, 9)

# %% [markdown]
# Before drop and after drop the duplicate values the dataset has same shape which meanse no duplicates values in the dataset.

# %%
#check for missing values, count them and print the sum for every column
df.isnull().sum()  # conclusion :- there are no null values in this dataset
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# **Check the no.of Zero values in dataset**

# %%
print('No.of zero values in Pregnancies :',df[df['Pregnancies']==0].shape[0])
# Out:
# No.of zero values in Pregnancies : 111

# %%
print('No.of zero values in Glucose :',df[df['Glucose']==0].shape[0])
print('No.of zero values in BloodPressure :',df[df['BloodPressure']==0].shape[0])
print('No.of zero values in SkinThickness :',df[df['SkinThickness']==0].shape[0])
print('No.of zero values in Insulin :',df[df['Insulin']==0].shape[0])
print('No.of zero values in BMI :',df[df['BMI']==0].shape[0])
print('No.of zero values in Age :',df[df['Age']==0].shape[0])
# Out:
# No.of zero values in Glucose : 5
# No.of zero values in BloodPressure : 35
# No.of zero values in SkinThickness : 227
# No.of zero values in Insulin : 374
# No.of zero values in BMI : 11
# No.of zero values in Age : 0

# %% [markdown]
# **Replace no.of zero values with mean of that columns**

# %%
df['Glucose']= df['Glucose'].replace(0,df['Glucose'].mean())
print('No.of zero values in Glucose :',df[df['Glucose']==0].shape[0])
# Out:
# No.of zero values in Glucose : 0

# %%
df['BloodPressure']= df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['SkinThickness']= df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df['Insulin']= df['Insulin'].replace(0,df['Insulin'].mean())
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  121.681605  ...   33.240885    0.348958
# std       3.369578   30.436016  ...   11.760232    0.476951
# min       0.000000   44.000000  ...   21.000000    0.000000
# 25%       1.000000   99.750000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.127964  ...  0.544341  0.221898
# Glucose                      0.127964  1.000000  ...  0.266600  0.492908
# BloodPressure                0.208984  0.219666  ...  0.326740  0.162986
# SkinThickness                0.013376  0.160766  ...  0.026423  0.175026
# Insulin                     -0.018082  0.396597  ...  0.038652  0.179185
# BMI                          0.021546  0.231478  ...  0.025748  0.312254
# DiabetesPedigreeFunction    -0.033523  0.137106  ...  0.033561  0.173844
# Age                          0.544341  0.266600  ...  1.000000  0.238356
# Outcome                      0.221898  0.492908  ...  0.238356  1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# **Step 5: Data Visulization**

# %% [markdown]
# **<h5>Hear we are going to plot<h5>**
#
# - Count Plot :- to see if the dataset is balanced or not
# - Histograms :- to see if data is normally distributed or skewed
# - Box Plot :- to analysis the distribution and see the outliers
# - Violin Plot :- to analysis the distribution and see the outliers
# - Scatter plots :- to understand relationship between any two variables
# - Pair plot :- to create scatter plot between all the variables

# %% [markdown]
# **Count Plot**

# %%
# Outcome Count Plot
f,ax=plt.subplots(1,2,figsize=(10,5))

mylabels = ['Nagetive','Positive']
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],labels=mylabels ,shadow=True)
ax[0].set_title('Outcome Position')
ax[0].set_ylabel('')

sns.countplot('Outcome',data=df,ax=ax[1])
ax[1].set_title('Outcome Position')

N,P=df['Outcome'].value_counts()
print('Outcome Total Values :',df['Outcome'].value_counts().sum())
print('Negative (0)',N)
print('Positive (1)',P)
plt.grid(axis='y')
plt.show()
# Out:
# Outcome Total Values : 768
# Negative (0) 500
# Positive (1) 268

# %% [markdown]
# - Out of total 768 people, 268 are dibetic (positive(1)) and - 500 are non-dibetic(negative(0)).
# - In the Outcome columns, **1** represent **diabetes positive** and **0** represents **diabetes negative**.
# - The countplot tells us that the database is **imbalanced**, as number of patients who don't have diabetes is more then those who have diabets.

# %% [markdown]
# **Histograms**
#
# - Histograms are one of the most common graph used to display numeric data.
# - distribution of the data - whether the data is normally distributed or if it's skewed (to the left or right)

# %%
# Histogram of each feature 
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# **Box Plot**

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(3,3,1)
sns.boxplot(x='Outcome',y ='Glucose',data=df)
plt.subplot(3,3,2)
sns.boxplot(x='Outcome',y='BloodPressure',data=df)
plt.subplot(3,3,3)
sns.boxplot(x='Outcome',y='Insulin',data=df)
plt.subplot(3,3,4)
sns.boxplot(x='Outcome',y='BMI',data=df)
plt.subplot(3,3,5)
sns.boxplot(x='Outcome',y='Age',data=df)
plt.subplot(3,3,6)
sns.boxplot(x='Outcome',y='SkinThickness',data=df)
plt.subplot(3,3,7)
sns.boxplot(x='Outcome',y='Pregnancies',data=df)
plt.subplot(3,3,8)
sns.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=df)
plt.show()

# %% [markdown]
# **Violin Plot**

# %%
plt.figure(figsize=(12,10))
sns.set_style(style='whitegrid')
plt.subplot(3,3,1)
sns.violinplot(x='Outcome',y ='Glucose',data=df)
plt.subplot(3,3,2)
sns.violinplot(x='Outcome',y='BloodPressure',data=df)
plt.subplot(3,3,3)
sns.violinplot(x='Outcome',y='Insulin',data=df)
plt.subplot(3,3,4)
sns.violinplot(x='Outcome',y='BMI',data=df)
plt.subplot(3,3,5)
sns.violinplot(x='Outcome',y='Age',data=df)
plt.subplot(3,3,6)
sns.violinplot(x='Outcome',y='SkinThickness',data=df)
plt.subplot(3,3,7)
sns.violinplot(x='Outcome',y='Pregnancies',data=df)
plt.subplot(3,3,8)
sns.violinplot(x='Outcome',y='DiabetesPedigreeFunction',data=df)
plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
# Scatter Plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(20,20));

# %% [markdown]
# **Pair Plot**

# %%
# Pair Plot
sns.pairplot(data=df, hue='Outcome')
plt.show()

# %% [markdown]
# **Step 6: Analyzing relationships between variables**

# %%
corrmat=df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corrmat,cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# **Observations:**
#
# - From the correlation heatmap, we can see that there is a high correlation between Outcome and [Pregnancies, Glucose, BMI, Age, Insulin]. We can select these features to accept input from the user and predict the outcome.

# %% [markdown]
# **Split the data frame into X & y**

# %%
target_name = 'Outcome'

# Separate object for target feature
y = df[target_name]

# Separate object for input Feature
X = df.drop(target_name,axis=1)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6    148.0           72.0  ...  33.6                     0.627   50
# 1            1     85.0           66.0  ...  26.6                     0.351   31
# 2            8    183.0           64.0  ...  23.3                     0.672   32
# 3            1     89.0           66.0  ...  28.1                     0.167   21
# 4            0    137.0           40.0  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# **Step 8: Apply Feature Scaling**

# %%
# Apply Standard Scaler

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
SSX = scaler.transform(X)

# %% [markdown]
# Inplace of Standard Scaler you have to try other data scaling techniques like normalizier,minmax scaler and binarizer.

# %% [markdown]
# **TRAIN TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(SSX,y,test_size=0.2, random_state=7)

# %%
# train data shape
X_train.shape,y_train.shape
# Out:
# ((614, 8), (614,))

# %%
# Test data shape
X_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %%
X_train
# Out:
# array([[0.29411765, 0.41290323, 0.48979592, ..., 0.36605317, 0.07899231,
#         0.2       ],
#        [0.11764706, 0.37419355, 0.63265306, ..., 0.55828221, 0.02092229,
#         0.03333333],
#        [0.23529412, 0.73548387, 0.55102041, ..., 0.3006135 , 0.30956447,
#         0.16666667],
#        ...,
#        [0.        , 0.08387097, 0.36734694, ..., 0.07157464, 0.28052946,
#         0.76666667],
#        [0.05882353, 0.39354839, 0.34693878, ..., 0.12474438, 0.04654142,
#         0.        ],
#        [0.47058824, 0.87096774, 0.48979592, ..., 0.29652352, 0.27369769,
#         0.25      ]])

# %%
y_train
# Out:
# 289    0
# 328    1
# 394    1
# 321    1
# 326    1
#       ..
# 579    1
# 502    1
# 537    0
# 196    0
# 175    1
# Name: Outcome, Length: 614, dtype: int64

# %% [markdown]
# **Step 9: Built the CLASSIFICATION Algorithms**

# %% [markdown]
# ## **kNeighborsClassifier(KNN) using grid search cv**

# %%
# import accourcy test library
from sklearn.metrics import accuracy_score

# %%
# import sklearn KNeighborsClassifier(KNN) and grid search cv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
knn = KNeighborsClassifier()
k_range = list(range(1, 31))
param_grid = dict(n_neighbors=k_range)

# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=15, scoring='accuracy', return_train_score=False,verbose=1)

# fitting the model for grid search
grid_search=grid.fit(X_train, y_train)
# Out:
# Fitting 15 folds for each of 30 candidates, totalling 450 fits

# %%
print("best_estimator result :-",grid_search.best_estimator_)
print("best_params result :-",grid_search.best_params_)
# Out:
# best_estimator result :- KNeighborsClassifier(n_neighbors=10)
# best_params result :- {'n_neighbors': 10}

# %%
y_pred = grid.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7532467532467533

# %%
knn = KNeighborsClassifier(n_neighbors=25)
knn.fit(X_train,y_train)
print('-'*50)

y_pred_train = knn.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data :',accuracy)

y_pred_test = knn.predict(X_test)
accuracy_1 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data :',accuracy_1)
print('-'*50)
print('-'*50)
# Out:
# --------------------------------------------------
# Accuracy for train data : 0.7687296416938111
# Accuracy for test data : 0.8246753246753247
# --------------------------------------------------
# --------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# ## Navie-Bayes Algorithm

# %%
# import sklearn naive_bayes 
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB(var_smoothing=1)
y_pred = gnb.fit(X_train,y_train).predict(X_test)
print('-'*50)
y_pred_train = gnb.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data Result :',accuracy)

y_pred_test = gnb.predict(X_test)
accuracy_2 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data Result :',accuracy_2)
print('-'*50)
# Out:
# --------------------------------------------------
# Accuracy for train data Result : 0.750814332247557
# Accuracy for test data Result : 0.7532467532467533
# --------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# ## Logistic-Regression Algroithm using grid search cv

# %%
# import Logistic-Regrassion and grid search cv
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}   # l1 lasso l2 ridge
logreg = LogisticRegression()

# defining parameter range
logreg_cv = GridSearchCV(logreg,grid,cv=10)

# fitting the model for grid search
grid_search_log=logreg_cv.fit(X_train, y_train)

# %%
print("best_estimator result :-",grid_search_log.best_estimator_)
print("best_params result :-",grid_search_log.best_params_)
# Out:
# best_estimator result :- LogisticRegression(C=100.0)
# best_params result :- {'C': 100.0, 'penalty': 'l2'}

# %%
grid_search_log.best_score_
# Out:
# 0.7719196192490745

# %%
# Accuracy test
y_pred = logreg_cv.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7727272727272727

# %%
logistic = LogisticRegression(C=10.0,penalty="l2")
y_pred = logistic.fit(X_train,y_train)
print('-'*50)

y_pred_train = logistic.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data Result :',accuracy)

y_pred_test = logistic.predict(X_test)
accuracy_3 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data Result :',accuracy_3)
print('-'*50)
# Out:
# --------------------------------------------------
# Accuracy for train data Result : 0.7736156351791531
# Accuracy for test data Result : 0.7792207792207793
# --------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# ## **Decision Tree Algrithm using grid search cv**

# %%
# import sklearn Decision Tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [5, 6, 7, 8, 9],
              'criterion' :['gini', 'entropy']
             }
tree_clas = DecisionTreeClassifier(random_state=1024)
grid_search = GridSearchCV(estimator=tree_clas, param_grid=param_grid, cv=5, verbose=True)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1024),
#              param_grid={'ccp_alpha': [0.1, 0.01, 0.001],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 6, 7, 8, 9],
#                          'max_features': ['auto', 'sqrt', 'log2']},
#              verbose=True)

# %%
final_model = grid_search.best_estimator_
final_model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, max_depth=6, max_features='log2',
#                        random_state=1024)

# %%
dici_class = DecisionTreeClassifier(max_depth=100)
y_pred = dici_class.fit(X_train,y_train)
print('-'*50)

y_pred_train = dici_class.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data Result :',accuracy)

y_pred_test = dici_class.predict(X_test)
accuracy_4 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data Result :',accuracy_4)
print('-'*50)
# Out:
# --------------------------------------------------
# Accuracy for train data Result : 1.0
# Accuracy for test data Result : 0.7792207792207793
# --------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1
# Out:
# array([[79, 18],
#        [16, 41]])

# %%
#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# ## **Random Forest Machine Learning Algorithm***

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random = RandomForestClassifier(n_estimators= 200, criterion="entropy")
y_pred = random.fit(X_train, y_train).predict(X_test)

y_pred_train = random.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data :',accuracy)

y_pred_test = random.predict(X_test)
accuracy_5 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data :',accuracy_5)
# Out:
# Accuracy for train data : 1.0
# Accuracy for test data : 0.7987012987012987

# %%
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1
#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# # Support vector machine Algorithm (SVM)

# %%
# import svm algorithm
from sklearn import svm

# %%
clf = svm.SVC(kernel='poly',degree=2)

y_pred = clf.fit(X_train,y_train).predict(X_test)

# %%
y_pred_train = clf.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data : ',accuracy)

y_pred_test = clf.predict(X_test)
accuracy_6 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data : ',accuracy_6)
# Out:
# Accuracy for train data :  0.7850162866449512
# Accuracy for test data :  0.8116883116883117

# %%
.
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test, y_pred_test)

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# # **Gradient Boosting Algorithm**

# %%
# import gradient boosting algorithm
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradi = GradientBoostingClassifier(n_estimators=20, learning_rate=1.0,
    max_depth=10, random_state=0)

y_pred = gradi.fit(X_train,y_train)

# %%
y_pred_train = gradi.predict(X_train)
accuracy = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data : ',accuracy)

y_pred_test = gradi.predict(X_test)
accuracy_7 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data : ',accuracy_7)
# Out:
# Accuracy for train data :  1.0
# Accuracy for test data :  0.8246753246753247

# %%
c_matrix_1 = confusion_matrix(y_test, y_pred_test)

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# #**<h3>Comparison<h3>**

# %%
#Lastly we have represented the optimal accuracy by comparing of all the algorithms applying the bar diagram

x = np.array(["Knn", "NaiveBayes", "LogisticRegression", "DecisionTree","RandomForest","SVM","GradientBoosting"])
y = np.array([accuracy_1, accuracy_2, accuracy_3,accuracy_4,accuracy_5,accuracy_6,accuracy_7])
plt.figure(figsize=(18,4))
plt.bar(x,y,width = 0.6)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# From above all the results, we can see that the **Gradient Boosting algorithm** has achieved **82.47% accuracy**, which is higher than the rest of the algorithms. Therefore, we can say that the RandomForest algorithm has better performance than others in the prediction of diabetics.
