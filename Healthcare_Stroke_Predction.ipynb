# %% [markdown]
# **Description :**
#
# The object of this Healthcare_Stroke Dataset is to predict whether patient has stroke(1) or not(0).The datasets consists of several medical predictor(independent) variable and one target variable(Stroke).Predictor variable includes id,gender,age,hypertension,heart_disease,ever_married,work_type,residence_type,avg_glucose_level,bmi,smoking_status and Stroke...

# %% [markdown]
# **Number of the columns with their meanings :**
#
# 1. Id : Id no (ID)
# 2. Gender : Male/Female / Other
# 3. Age : Age(Years)
# 4. hypertension :
# 5. heart_disease:
# 6. ever_married : Yes of No
# 7. work_type : Private / Self-Employe / Govt jod / Never_worked / children
# 8. Residence_type :
# 9. Avg_glucose_level :
# 10. Bmi : Body mess index
# 11. Smoking_status : formerly smoked / Never somked / smoked
# 12. Stroke : Class Variable(0 or 1)
#          . 4861 of 5110 are (not stroke) 0
#          . 249 of 5110 are (stroke) 1

# %% [markdown]
# **Step 1:- Importing libraries like Numpy,Pandas,Matplotlib & Seaborn**

# %%
# Numpy 
import numpy as np

# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt

# Seaborn
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Step 2:- Load Dataset**

# %%
# Dataset load 
df = pd.read_csv('/content/drive/MyDrive/ML_DataFile/healthcare-dataset-stroke-data.csv')
df
# Out:
#          id  gender   age  ...   bmi   smoking_status stroke
# 0      9046    Male  67.0  ...  36.6  formerly smoked      1
# 1     51676  Female  61.0  ...   NaN     never smoked      1
# 2     31112    Male  80.0  ...  32.5     never smoked      1
# 3     60182  Female  49.0  ...  34.4           smokes      1
# 4      1665  Female  79.0  ...  24.0     never smoked      1
# ...     ...     ...   ...  ...   ...              ...    ...
# 5105  18234  Female  80.0  ...   NaN     never smoked      0
# 5106  44873  Female  81.0  ...  40.0     never smoked      0
# 5107  19723  Female  35.0  ...  30.6     never smoked      0
# 5108  37544    Male  51.0  ...  25.6  formerly smoked      0
# 5109  44679  Female  44.0  ...  26.2          Unknown      0
#
# [5110 rows x 12 columns]

# %% [markdown]
# # **Step 3:- Exploratory Data Analysis**

# %%
#get familier with dataset, display the top 5 data records
df.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0   9046    Male  67.0  ...  36.6  formerly smoked      1
# 1  51676  Female  61.0  ...   NaN     never smoked      1
# 2  31112    Male  80.0  ...  32.5     never smoked      1
# 3  60182  Female  49.0  ...  34.4           smokes      1
# 4   1665  Female  79.0  ...  24.0     never smoked      1
#
# [5 rows x 12 columns]

# %%
# get familier with dataset, display the last 5 data records
df.tail()
# Out:
#          id  gender   age  ...   bmi   smoking_status stroke
# 5105  18234  Female  80.0  ...   NaN     never smoked      0
# 5106  44873  Female  81.0  ...  40.0     never smoked      0
# 5107  19723  Female  35.0  ...  30.6     never smoked      0
# 5108  37544    Male  51.0  ...  25.6  formerly smoked      0
# 5109  44679  Female  44.0  ...  26.2          Unknown      0
#
# [5 rows x 12 columns]

# %%
# get familier with dataset, display randomly 5 data records
df.sample(5)
# Out:
#          id  gender   age  ...   bmi  smoking_status stroke
# 2905  63236    Male  65.0  ...  41.2          smokes      0
# 226   32729  Female  81.0  ...  27.5    never smoked      1
# 1871  21608    Male  56.0  ...  23.8          smokes      0
# 4568  42400  Female   2.0  ...  20.4         Unknown      0
# 69     7371  Female  80.0  ...  28.9    never smoked      1
#
# [5 rows x 12 columns]

# %%
# getting to know about rows and columns we're dealing with - 768 rows , 9 columns
df.shape
# Out:
# (5110, 12)

# %%
# learning about the columns
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# knowledge of data type helps for computation
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
#  Print a concise summary of a DataFrame. 
#  This method prints information about a DataFrame including the index dtype and columns,
#  non-null values and memory usage

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
 #helps us to understand how data has been spread across the table.
# count :- the number of NoN-empty rows in a feature.
# mean :- mean value of that feature.
# std :- Standard Deviation Value of that feature.
# min :- minimum value of that feature.
# max :- maximum value of that feature.
# 25%, 50%, and 75% are the percentile/quartile of each features.

df.describe()
# Out:
#                  id          age  ...          bmi       stroke
# count   5110.000000  5110.000000  ...  4909.000000  5110.000000
# mean   36517.829354    43.226614  ...    28.893237     0.048728
# std    21161.721625    22.612647  ...     7.854067     0.215320
# min       67.000000     0.080000  ...    10.300000     0.000000
# 25%    17741.250000    25.000000  ...    23.500000     0.000000
# 50%    36932.000000    45.000000  ...    28.100000     0.000000
# 75%    54682.000000    61.000000  ...    33.100000     0.000000
# max    72940.000000    82.000000  ...    97.600000     1.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# Summary of Dataset :
#
# The described method will help to see how data has been spread of numerical values. We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %% [markdown]
# #**Step 4:- Data Cleaning**

# %%
# Check the shape before the duplicate values
df.shape
# Out:
# (5110, 12)

# %%
#Count duplicates values
df.duplicated().sum()
# Out:
# 0

# %%
# if there are duplicates values, this code duplicate values drop ..
df = df.drop_duplicates()

# %%
# Drop id and residence_type columns
df = df.drop(['id','Residence_type'],axis=1)
df.head()
# Out:
#    gender   age  hypertension  ...   bmi   smoking_status stroke
# 0    Male  67.0             0  ...  36.6  formerly smoked      1
# 1  Female  61.0             0  ...   NaN     never smoked      1
# 2    Male  80.0             0  ...  32.5     never smoked      1
# 3  Female  49.0             0  ...  34.4           smokes      1
# 4  Female  79.0             1  ...  24.0     never smoked      1
#
# [5 rows x 10 columns]

# %%
# check the shape after drop the duplicate values
df.shape
# Out:
# (5110, 10)

# %%
# Count of null nalues
# chack the missing values in any columns
# Display number of null values in ever columns in dataset

df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# BMI columns **201** null values in this dataset

# %% [markdown]
# **Check the no.of NaN values in Bmi columns**

# %%
print('No of NaN values in Bmi :',df[df['bmi']=='NaN'].shape[0])
# Out:
# No of NaN values in Bmi : 0

# %% [markdown]
# **Replace no.of NaN values with mean of that Bmi columns**

# %%
mean_value=df['bmi'].mean()

# %%
df['bmi'].fillna(value=df['bmi'].mean(), inplace=True)

# %%
# Count of null nalues
# chack the missing values in any columns
# Display number of null values in ever columns in dataset

df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# **No Null Values in this dataset**

# %%
df.describe()
# Out:
#                age  hypertension  ...          bmi       stroke
# count  5110.000000   5110.000000  ...  5110.000000  5110.000000
# mean     43.226614      0.097456  ...    28.893237     0.048728
# std      22.612647      0.296607  ...     7.698018     0.215320
# min       0.080000      0.000000  ...    10.300000     0.000000
# 25%      25.000000      0.000000  ...    23.800000     0.000000
# 50%      45.000000      0.000000  ...    28.400000     0.000000
# 75%      61.000000      0.000000  ...    32.800000     0.000000
# max      82.000000      1.000000  ...    97.600000     1.000000
#
# [8 rows x 6 columns]

# %%
df.corr()
# Out:
#                         age  hypertension  ...       bmi    stroke
# age                1.000000      0.276398  ...  0.325942  0.245257
# hypertension       0.276398      1.000000  ...  0.160189  0.127904
# heart_disease      0.263796      0.108306  ...  0.038899  0.134914
# avg_glucose_level  0.238171      0.174474  ...  0.168751  0.131945
# bmi                0.325942      0.160189  ...  1.000000  0.038947
# stroke             0.245257      0.127904  ...  0.038947  1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# # **Step 5: Data Visulization**

# %% [markdown]
# **Hear we are going to plot**
# - Count Plot :- to see if the dataset is balanced or not
# - Histograms :- to see if data is normally distributed or skewed
# - Pair plot :- to create scatter plot between all the variables

# %%
# Stroke rate Count Plot

f,ax=plt.subplots(1,2,figsize=(16,6))

mylabels = ['Nagetive','Positive']
df['stroke'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],labels=mylabels ,shadow=True)
ax[0].set_title('Stroke Position',size=16)
ax[0].set_ylabel('')

sns.countplot('stroke',data=df,ax=ax[1])
ax[1].set_title('Stroke Position',size=16)

N,P=df['stroke'].value_counts()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# . Out of total 5110 people, 249 are stroke (positive(1)) and 4861 are not stroke negative(0)
#
# .  In the Stroke columns, 1 represent stroke positive and 0 represents stroke negative.
#
# .  The countplot tells us that the database is imbalanced, as number of patients who don't have stroke is more then those who have stroke.

# %% [markdown]
# **Histograms**

# %%
# Histogram of each feature
df.hist(bins=10,figsize=(10,10))
plt.show()

# %%
# Stroke Rate
sns.countplot('stroke',data=df)
df['gender'].value_counts()
plt.title('Stroke Rate',color='g',size=15)
plt.xlabel('Stroke')
plt.ylabel('Gander Count')
plt.show()

# %%
# Gander Division Count
sns.countplot('gender',data=df)
df['gender'].value_counts()
plt.title('Gander Division Count',color='g',size=15)
plt.xlabel('Stroke')
plt.ylabel('Gander Count')
plt.show()

# %%
# Gander Division Stroke Rate
sns.countplot('gender', data=df, hue='stroke')
plt.title('Gander Division Stroke Rate',color='g',size=15)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
# Ever_married
sns.countplot('ever_married',data=df)
plt.title('Ever Married',color='g',size=15)
plt.show()

# %%
# Ever_married stroke rate
sns.countplot('ever_married',data=df,hue='stroke')
plt.title('Ever Married Stroke Rate',color='g',size=15)
plt.show()

# %%
# Work_type
sns.countplot('work_type',data=df)
df['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
# Work_type Stroke Rate
sns.countplot('work_type',data=df,hue='stroke')
plt.title('Work Type Stroke Rate',color='g',size=15)
plt.show()

# %%
# Somking_Status

sns.countplot('smoking_status',data=df)
df['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
# Somking_Status Stroke Rate

sns.countplot('smoking_status',data=df,hue='stroke')
plt.title('Smoking_Status Stroke Rate',color='g',size=15)
plt.show()

# %%
# Scatter Plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(20,20));

# %%
# pair Plot
sns.pairplot(data=df,hue='stroke')
plt.show()

# %%
# Analysis relationships between variables
corrmat=df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corrmat,cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# **Observation**
#
# Form the correlation heatmap,we can see that there is a high correlation between stroke and [age,bmi,hypertension].
# We can select these features to accept input from the user and predict the stroke.

# %% [markdown]
# # **LabelEncoding String to Float convert**

# %%
# import label encoder
from sklearn import preprocessing

# %%
# Gender,work_type,ever_married and smoking_status LableEncoding string to float


le = preprocessing.LabelEncoder()
df['gender']=le.fit_transform(df['gender'])
df['work_type']=le.fit_transform(df['work_type'])
df['ever_married']=le.fit_transform(df['ever_married'])
df['smoking_status']=le.fit_transform(df['smoking_status'])

# %%
df.head()
# Out:
#    gender   age  hypertension  ...        bmi  smoking_status  stroke
# 0       1  67.0             0  ...  36.600000               1       1
# 1       0  61.0             0  ...  28.893237               2       1
# 2       1  80.0             0  ...  32.500000               2       1
# 3       0  49.0             0  ...  34.400000               3       1
# 4       0  79.0             1  ...  24.000000               2       1
#
# [5 rows x 10 columns]

# %% [markdown]
# #**Apply Feature Scaling**

# %%
# Apply Standard Scaler

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
SSX = scaler.transform(X)

# %% [markdown]
# Inplace of Standard Scaler you have to try other data scaling techniques like normalizer,min-max scaler, and binarized.

# %% [markdown]
# # **Split The Data Frame into X & y**

# %%
# Target Variavle

target_name = 'stroke'

# Seprate object for target feature
y = df[target_name]

# Seprate object for input features
X = df.drop(target_name,axis=1)

# %%
# Input Value check
X.head()
# Out:
#    gender   age  hypertension  ...  avg_glucose_level        bmi  smoking_status
# 0       1  67.0             0  ...             228.69  36.600000               1
# 1       0  61.0             0  ...             202.21  28.893237               2
# 2       1  80.0             0  ...             105.92  32.500000               2
# 3       0  49.0             0  ...             171.23  34.400000               3
# 4       0  79.0             1  ...             174.12  24.000000               2
#
# [5 rows x 9 columns]

# %%
# Target Value check
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: stroke, dtype: int64

# %%
# X values and y values shape check
X.shape , y.shape
# Out:
# ((5110, 9), (5110,))

# %% [markdown]
# #**Train data Test data split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Train Data Test data shape

X_train.shape,X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4088, 9), (1022, 9), (4088,), (1022,))

# %%
X_train.head()
# Out:
#       gender   age  hypertension  ...  avg_glucose_level        bmi  smoking_status
# 2894       0  44.0             0  ...              97.27  26.000000               2
# 2427       0  37.0             0  ...              77.37  21.400000               2
# 1730       1  69.0             1  ...             107.11  28.893237               3
# 647        0  58.0             0  ...              82.01  34.700000               1
# 1746       1  24.0             1  ...              80.63  28.200000               3
#
# [5 rows x 9 columns]

# %%
y_train.head()
# Out:
# 2894    0
# 2427    0
# 1730    0
# 647     0
# 1746    0
# Name: stroke, dtype: int64

# %% [markdown]
# # **Built The Classification Algorithm**

# %% [markdown]
# # **Model Traning KNN using grid search cv**

# %%
# import accourcy test library
from sklearn.metrics import accuracy_score

# %%
# import sklearn KNeighborsClassifier(KNN) and grid search cv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV


knn = KNeighborsClassifier()
k_range = list(range(1, 31))
param_grid = dict(n_neighbors=k_range)
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=15, scoring='accuracy', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search=grid.fit(X_train, y_train)
# Out:
# Fitting 15 folds for each of 30 candidates, totalling 450 fits

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
print('-'*50)

y_pred_train = knn.predict(X_train)
accuracy_1 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data :',accuracy_1)

y_pred_test = knn.predict(X_test)
accuracy_1 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data :',accuracy_1)
print('-'*50)
print('-'*50)
# Out:
# --------------------------------------------------
# Accuracy for train data : 0.9562133072407045
# Accuracy for test data : 0.9500978473581213
# --------------------------------------------------
# --------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Navie-Bayes Algorthm**

# %%
# import sklearn naive_bayes 
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB(var_smoothing=1)
y_pred = gnb.fit(X_train,y_train).predict(X_test)

y_pred_train = gnb.predict(X_train)
accuracy_2 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data Result :',accuracy_2)

y_pred_test = gnb.predict(X_test)
accuracy_2 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data Result :',accuracy_2)
# Out:
# Accuracy for train data Result : 0.9510763209393346
# Accuracy for test data Result : 0.952054794520548

# %%
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Logistic-Regression Algroithm using grid search cv**

# %%
# import Logistic-Regrassion and grid search cv
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}   # l1 lasso l2 ridge
logreg = LogisticRegression()

# defining parameter range
logreg_cv = GridSearchCV(logreg,grid,cv=10)

# fitting the model for grid search
grid_search_log=logreg_cv.fit(X_train, y_train)

# %%
logistic = LogisticRegression(C=10.0,penalty="l2")
y_pred = logistic.fit(X_train,y_train)


y_pred_train = logistic.predict(X_train)
accuracy_3 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data Result :',accuracy_3)

y_pred_test = logistic.predict(X_test)
accuracy_3 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data Result :',accuracy_3)
# Out:
# Accuracy for train data Result : 0.950587084148728
# Accuracy for test data Result : 0.9530332681017613

# %%
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Decision Tree Algrithm using grid search cv**

# %%
# import sklearn Decision Tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [5, 6, 7, 8, 9],
              'criterion' :['gini', 'entropy']
             }
tree_clas = DecisionTreeClassifier(random_state=1024)
grid_search = GridSearchCV(estimator=tree_clas, param_grid=param_grid, cv=5, verbose=True)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1024),
#              param_grid={'ccp_alpha': [0.1, 0.01, 0.001],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 6, 7, 8, 9],
#                          'max_features': ['auto', 'sqrt', 'log2']},
#              verbose=True)

# %%
dici_class = DecisionTreeClassifier(max_depth=100)
y_pred = dici_class.fit(X_train,y_train)


y_pred_train = dici_class.predict(X_train)
accuracy_4 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data Result :',accuracy_4)

y_pred_test = dici_class.predict(X_test)
accuracy_4 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data Result :',accuracy_4)
# Out:
# Accuracy for train data Result : 1.0
# Accuracy for test data Result : 0.901174168297456

# %%
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Random Forest Machine Learning Algorithm**

# %%
# import sklearn Random Forest 
from sklearn.ensemble import RandomForestClassifier

# %%
random = RandomForestClassifier(n_estimators= 200, criterion="entropy")
y_pred = random.fit(X_train, y_train).predict(X_test)

y_pred_train = random.predict(X_train)
accuracy_5 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data :',accuracy_5)

y_pred_test = random.predict(X_test)
accuracy_5 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data :',accuracy_5)
# Out:
# Accuracy for train data : 1.0
# Accuracy for test data : 0.9500978473581213

# %%
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Support vector machine Algorithm (SVM)**

# %%
# import svm algorithm
from sklearn import svm

# %%
clf = svm.SVC(kernel='poly',degree=2)

y_pred = clf.fit(X_train,y_train).predict(X_test)

# %%
y_pred_train = clf.predict(X_train)
accuracy_6 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data : ',accuracy_6)

y_pred_test = clf.predict(X_test)
accuracy_6 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data : ',accuracy_6)

# %%
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Gradient Boosting Algorithm**

# %%
# import gradient boosting algorithm
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradi = GradientBoostingClassifier(n_estimators=20, learning_rate=1.0,
    max_depth=10, random_state=0)

y_pred = gradi.fit(X_train,y_train)

# %%
y_pred_train = gradi.predict(X_train)
accuracy_7 = accuracy_score(y_train,y_pred_train)
print('Accuracy for train data : ',accuracy_7)

y_pred_test = gradi.predict(X_test)
accuracy_7 = accuracy_score(y_test,y_pred_test)
print('Accuracy for test data : ',accuracy_7)

# %%
c_matrix_1 = confusion_matrix(y_test,y_pred_test)
c_matrix_1

#Utilizing the heatmap function we have presented the confusion matrix.
sns.heatmap(c_matrix_1 , cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ## **Comparison**

# %%
#Lastly we have represented the optimal accuracy by comparing of all the algorithms applying the bar diagram

x = np.array(["Knn", "NaiveBayes", "LogisticRegression", "DecisionTree","RandomForest","SVM","GradientBoosting"])
y = np.array([accuracy_1, accuracy_2, accuracy_3,accuracy_4,accuracy_5,accuracy_6,accuracy_7])
plt.figure(figsize=(18,6))
plt.bar(x,y,width = 0.6)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# From above all the results, we can see that the **Random Forest Algorithm** has achieved **94.94% accuracy**, which is higher than the rest of the algorithms. Therefore, we can say that the RandomForest algorithm has better performance than others in the prediction of diabetics.
